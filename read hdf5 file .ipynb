# %%
import h5py
import os, time
import tensorflow as tf
from matplotlib import pyplot as plt, cm
import numpy as np
import glob, os
import ntpath
import SimpleITK as sitk
import cv2

# %matplotlib inline

print(tf.__version__)

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())


filename = "C:/Users/Kevin/Desktop/Folders/Visual Code Studio/UROP/modl-master/dataset_256.hdf5"

mask = []
org = []
csm = []

with h5py.File(filename, "r") as f:
    #List all groups
    print(list(f.keys()))
    arr = list(f.keys())
    for n in range(3):
        a = arr[n]
        dset = f[a]
        print(dset)
        print(dset.name)      
        

    mask,csm=f['tstMask'][:],f['tstCsm'][:]
    org = f['tstOrg'][:]
    
    
    csm = csm.astype("float64")
     
    
for img_bundle in csm[:1]:
    for img in img_bundle[:2]:
        plt.imshow(img)
        plt.show()
    print("next")
        
for img in mask[:1]:
    
    plt.imshow(img)
    plt.show()
# Out:
# 2.6.0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15916305217176180416
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2255906407
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2872458375143707877
# physical_device_desc: "device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]
# ['trnCsm', 'trnMask', 'trnOrg', 'tstCsm', 'tstMask', 'tstOrg']
# <HDF5 dataset "trnCsm": shape (360, 12, 256, 232), type "<c8">
# /trnCsm
# <HDF5 dataset "trnMask": shape (360, 256, 232), type "|i1">
# /trnMask
# <HDF5 dataset "trnOrg": shape (360, 256, 232), type "<c8">
# /trnOrg
# C:\Users\Kevin\AppData\Local\Temp/ipykernel_25552/1263573200.py:41: ComplexWarning: Casting complex values to real discards the imaginary part
#   csm = csm.astype("float64")
# next
